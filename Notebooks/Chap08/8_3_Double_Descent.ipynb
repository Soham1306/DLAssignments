# %% [markdown]
# <a href="https://colab.research.google.com/github/Soham1306/DLAssignments/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-3wes89bl
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-3wes89bl
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=d5d1a7412e859dbe3d14e89fd02e14ce36bba8727d7295f8fa822ea2b6d50548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_kf9cxij/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302483, train error 89.72,  test loss 2.302614, test error 90.30
# Epoch   100, train loss 2.302355, train error 89.65,  test loss 2.302950, test error 89.88
# Epoch   200, train loss 2.302361, train error 89.65,  test loss 2.302940, test error 89.88
# Epoch   300, train loss 2.302359, train error 89.65,  test loss 2.302923, test error 89.88
# Epoch   400, train loss 2.302359, train error 89.65,  test loss 2.302915, test error 89.88
# Epoch   500, train loss 2.302355, train error 89.65,  test loss 2.302998, test error 89.88
# Epoch   600, train loss 2.302361, train error 89.65,  test loss 2.302927, test error 89.88
# Epoch   700, train loss 2.302354, train error 89.65,  test loss 2.302937, test error 89.88
# Epoch   800, train loss 2.302356, train error 89.65,  test loss 2.302977, test error 89.88
# Epoch   900, train loss 2.302358, train error 89.72,  test loss 2.302948, test error 90.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.274825, train error 89.78,  test loss 2.258775, test error 89.18
# Epoch   100, train loss 1.746546, train error 63.95,  test loss 1.575593, test error 60.45
# Epoch   200, train loss 1.733140, train error 64.25,  test loss 1.579287, test error 60.25
# Epoch   300, train loss 1.729643, train error 63.62,  test loss 1.577591, test error 60.88
# Epoch   400, train loss 1.724005, train error 62.70,  test loss 1.574536, test error 60.33
# Epoch   500, train loss 1.719229, train error 62.85,  test loss 1.575245, test error 60.58
# Epoch   600, train loss 1.714216, train error 62.97,  test loss 1.575274, test error 60.42
# Epoch   700, train loss 1.711061, train error 62.62,  test loss 1.571758, test error 60.22
# Epoch   800, train loss 1.711281, train error 62.72,  test loss 1.574463, test error 61.22
# Epoch   900, train loss 1.710333, train error 62.75,  test loss 1.574301, test error 61.05
# Training model with   6 hidden variables
# Epoch     0, train loss 2.247348, train error 86.28,  test loss 2.228987, test error 85.90
# Epoch   100, train loss 1.679290, train error 59.55,  test loss 1.479465, test error 56.83
# Epoch   200, train loss 1.648785, train error 58.28,  test loss 1.468270, test error 57.55
# Epoch   300, train loss 1.618099, train error 56.80,  test loss 1.464539, test error 57.47
# Epoch   400, train loss 1.612303, train error 57.12,  test loss 1.465366, test error 57.15
# Epoch   500, train loss 1.614621, train error 57.50,  test loss 1.480818, test error 57.97
# Epoch   600, train loss 1.608241, train error 56.90,  test loss 1.472230, test error 57.67
# Epoch   700, train loss 1.611711, train error 56.15,  test loss 1.480301, test error 56.70
# Epoch   800, train loss 1.601587, train error 56.05,  test loss 1.470214, test error 56.62
# Epoch   900, train loss 1.601182, train error 56.03,  test loss 1.478234, test error 56.12
# Training model with   8 hidden variables
# Epoch     0, train loss 2.199154, train error 83.85,  test loss 2.172817, test error 82.97
# Epoch   100, train loss 1.644608, train error 57.50,  test loss 1.520701, test error 58.72
# Epoch   200, train loss 1.599156, train error 56.20,  test loss 1.485236, test error 56.55
# Epoch   300, train loss 1.572986, train error 55.38,  test loss 1.475297, test error 56.90
# Epoch   400, train loss 1.568719, train error 56.20,  test loss 1.476639, test error 57.03
# Epoch   500, train loss 1.561113, train error 54.92,  test loss 1.475322, test error 56.53
# Epoch   600, train loss 1.567910, train error 53.90,  test loss 1.493793, test error 57.03
# Epoch   700, train loss 1.567428, train error 54.50,  test loss 1.493958, test error 57.28
# Epoch   800, train loss 1.556898, train error 54.45,  test loss 1.480821, test error 56.58
# Epoch   900, train loss 1.568037, train error 54.88,  test loss 1.504327, test error 57.10
# Training model with  10 hidden variables
# Epoch     0, train loss 2.201743, train error 81.62,  test loss 2.172473, test error 80.50
# Epoch   100, train loss 1.509376, train error 52.42,  test loss 1.392984, test error 51.78
# Epoch   200, train loss 1.442138, train error 50.10,  test loss 1.338097, test error 49.47
# Epoch   300, train loss 1.425085, train error 49.35,  test loss 1.348119, test error 49.90
# Epoch   400, train loss 1.414950, train error 49.20,  test loss 1.348628, test error 49.78
# Epoch   500, train loss 1.410320, train error 49.05,  test loss 1.356022, test error 50.65
# Epoch   600, train loss 1.400761, train error 49.08,  test loss 1.354392, test error 49.55
# Epoch   700, train loss 1.399292, train error 48.90,  test loss 1.352540, test error 49.55
# Epoch   800, train loss 1.392382, train error 48.47,  test loss 1.366024, test error 50.40
# Epoch   900, train loss 1.390308, train error 48.25,  test loss 1.361753, test error 50.17
# Training model with  14 hidden variables
# Epoch     0, train loss 2.212828, train error 83.55,  test loss 2.194547, test error 81.65
# Epoch   100, train loss 1.411508, train error 47.88,  test loss 1.286514, test error 47.20
# Epoch   200, train loss 1.333905, train error 44.92,  test loss 1.305760, test error 47.65
# Epoch   300, train loss 1.305811, train error 43.58,  test loss 1.344384, test error 49.03
# Epoch   400, train loss 1.286234, train error 43.40,  test loss 1.356544, test error 49.22
# Epoch   500, train loss 1.277789, train error 42.88,  test loss 1.370474, test error 48.53
# Epoch   600, train loss 1.274559, train error 42.92,  test loss 1.404485, test error 49.20
# Epoch   700, train loss 1.258152, train error 42.35,  test loss 1.411419, test error 48.67
# Epoch   800, train loss 1.249486, train error 41.92,  test loss 1.440019, test error 49.20
# Epoch   900, train loss 1.246365, train error 42.15,  test loss 1.465687, test error 49.30
# Training model with  18 hidden variables
# Epoch     0, train loss 2.174017, train error 80.68,  test loss 2.159211, test error 81.32
# Epoch   100, train loss 1.362737, train error 45.75,  test loss 1.385847, test error 50.90
# Epoch   200, train loss 1.271216, train error 42.45,  test loss 1.385894, test error 50.38
# Epoch   300, train loss 1.225605, train error 41.25,  test loss 1.402983, test error 50.22
# Epoch   400, train loss 1.199918, train error 41.28,  test loss 1.471743, test error 51.08
# Epoch   500, train loss 1.189797, train error 40.67,  test loss 1.492266, test error 51.28
# Epoch   600, train loss 1.172860, train error 40.30,  test loss 1.548948, test error 51.22
# Epoch   700, train loss 1.154286, train error 39.30,  test loss 1.594839, test error 51.38
# Epoch   800, train loss 1.150819, train error 38.97,  test loss 1.658003, test error 52.25
# Epoch   900, train loss 1.139321, train error 38.78,  test loss 1.681829, test error 51.95
# Training model with  22 hidden variables
# Epoch     0, train loss 2.168195, train error 81.32,  test loss 2.140551, test error 80.00
# Epoch   100, train loss 1.290146, train error 43.05,  test loss 1.347476, test error 50.58
# Epoch   200, train loss 1.166654, train error 39.12,  test loss 1.403890, test error 51.45
# Epoch   300, train loss 1.108019, train error 37.10,  test loss 1.484949, test error 52.25
# Epoch   400, train loss 1.085903, train error 36.42,  test loss 1.552386, test error 52.50
# Epoch   500, train loss 1.055817, train error 35.45,  test loss 1.576748, test error 52.47
# Epoch   600, train loss 1.040780, train error 35.15,  test loss 1.631862, test error 53.97
# Epoch   700, train loss 1.026159, train error 34.78,  test loss 1.668320, test error 53.62
# Epoch   800, train loss 0.997304, train error 33.38,  test loss 1.719367, test error 53.85
# Epoch   900, train loss 0.997021, train error 33.05,  test loss 1.779696, test error 54.67
# Training model with  26 hidden variables
# Epoch     0, train loss 2.108908, train error 78.12,  test loss 2.052990, test error 78.28
# Epoch   100, train loss 1.186598, train error 40.05,  test loss 1.364661, test error 50.28
# Epoch   200, train loss 1.066762, train error 36.15,  test loss 1.499920, test error 52.50
# Epoch   300, train loss 0.984502, train error 33.20,  test loss 1.602524, test error 52.78
# Epoch   400, train loss 0.935608, train error 31.80,  test loss 1.694356, test error 53.58
# Epoch   500, train loss 0.914902, train error 31.20,  test loss 1.784428, test error 53.75
# Epoch   600, train loss 0.892312, train error 30.62,  test loss 1.839858, test error 53.30
# Epoch   700, train loss 0.858385, train error 28.85,  test loss 1.914911, test error 54.08
# Epoch   800, train loss 0.852335, train error 29.47,  test loss 1.998139, test error 54.45
# Epoch   900, train loss 0.830437, train error 27.80,  test loss 2.006530, test error 53.38
# Training model with  30 hidden variables
# Epoch     0, train loss 2.154704, train error 79.10,  test loss 2.144607, test error 79.43
# Epoch   100, train loss 1.127018, train error 37.88,  test loss 1.388083, test error 51.10
# Epoch   200, train loss 0.927001, train error 31.40,  test loss 1.592658, test error 52.42
# Epoch   300, train loss 0.832857, train error 27.80,  test loss 1.785401, test error 52.72
# Epoch   400, train loss 0.755034, train error 25.18,  test loss 2.008175, test error 53.30
# Epoch   500, train loss 0.708876, train error 23.68,  test loss 2.197288, test error 54.38
# Epoch   600, train loss 0.692492, train error 23.25,  test loss 2.445243, test error 55.53
# Epoch   700, train loss 0.657883, train error 22.88,  test loss 2.627970, test error 55.70
# Epoch   800, train loss 0.621024, train error 21.25,  test loss 2.755259, test error 55.10
# Epoch   900, train loss 0.617957, train error 22.03,  test loss 2.962894, test error 56.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.135647, train error 79.97,  test loss 2.112991, test error 80.10
# Epoch   100, train loss 1.026398, train error 32.82,  test loss 1.370353, test error 48.33
# Epoch   200, train loss 0.776169, train error 25.45,  test loss 1.678290, test error 50.53
# Epoch   300, train loss 0.647286, train error 21.32,  test loss 1.981557, test error 50.67
# Epoch   400, train loss 0.576400, train error 18.28,  test loss 2.337577, test error 52.65
# Epoch   500, train loss 0.551002, train error 18.95,  test loss 2.623560, test error 53.70
# Epoch   600, train loss 0.500425, train error 16.85,  test loss 2.904318, test error 53.67
# Epoch   700, train loss 0.472089, train error 15.82,  test loss 3.166615, test error 53.17
# Epoch   800, train loss 0.427521, train error 14.32,  test loss 3.525055, test error 55.35
# Epoch   900, train loss 0.445233, train error 15.53,  test loss 3.769943, test error 54.67
# Training model with  40 hidden variables
# Epoch     0, train loss 2.089563, train error 78.25,  test loss 2.040771, test error 76.93
# Epoch   100, train loss 0.942354, train error 29.80,  test loss 1.430771, test error 49.53
# Epoch   200, train loss 0.686374, train error 21.93,  test loss 1.922280, test error 53.53
# Epoch   300, train loss 0.523666, train error 16.45,  test loss 2.430942, test error 52.45
# Epoch   400, train loss 0.440157, train error 14.38,  test loss 3.068170, test error 54.62
# Epoch   500, train loss 0.362180, train error 11.82,  test loss 3.743186, test error 55.30
# Epoch   600, train loss 0.360571, train error 11.60,  test loss 4.442552, test error 54.75
# Epoch   700, train loss 0.304410, train error 10.82,  test loss 5.012174, test error 55.88
# Epoch   800, train loss 0.246222, train error 8.15,  test loss 5.825893, test error 56.70
# Epoch   900, train loss 0.339366, train error 12.78,  test loss 6.539438, test error 57.25
# Training model with  45 hidden variables
# Epoch     0, train loss 2.097964, train error 77.45,  test loss 2.060696, test error 76.68
# Epoch   100, train loss 0.841181, train error 27.38,  test loss 1.542216, test error 51.10
# Epoch   200, train loss 0.515131, train error 17.35,  test loss 2.305522, test error 53.67
# Epoch   300, train loss 0.328359, train error 10.95,  test loss 3.374186, test error 54.47
# Epoch   400, train loss 0.210776, train error 6.75,  test loss 4.504784, test error 54.85
# Epoch   500, train loss 0.207268, train error 6.85,  test loss 5.889811, test error 56.08
# Epoch   600, train loss 0.135337, train error 4.62,  test loss 6.958704, test error 56.08
# Epoch   700, train loss 0.294175, train error 9.55,  test loss 8.202380, test error 56.70
# Epoch   800, train loss 0.007560, train error 0.00,  test loss 9.093193, test error 56.92
# Epoch   900, train loss 0.004953, train error 0.00,  test loss 9.608557, test error 56.80
# Training model with  50 hidden variables
# Epoch     0, train loss 2.052484, train error 76.47,  test loss 2.009991, test error 77.18
# Epoch   100, train loss 0.710976, train error 20.93,  test loss 1.598778, test error 50.33
# Epoch   200, train loss 0.354087, train error 10.35,  test loss 2.619270, test error 52.53
# Epoch   300, train loss 0.174191, train error 4.78,  test loss 4.045680, test error 53.42
# Epoch   400, train loss 0.033677, train error 0.05,  test loss 5.621904, test error 54.42
# Epoch   500, train loss 0.013044, train error 0.00,  test loss 6.656500, test error 54.47
# Epoch   600, train loss 0.008119, train error 0.00,  test loss 7.307869, test error 54.78
# Epoch   700, train loss 0.005790, train error 0.00,  test loss 7.772306, test error 54.70
# Epoch   800, train loss 0.004405, train error 0.00,  test loss 8.156650, test error 54.55
# Epoch   900, train loss 0.003533, train error 0.00,  test loss 8.469686, test error 54.70
# Training model with  55 hidden variables
# Epoch     0, train loss 2.036446, train error 76.38,  test loss 1.980159, test error 76.47
# Epoch   100, train loss 0.627471, train error 19.35,  test loss 1.689902, test error 50.97
# Epoch   200, train loss 0.208434, train error 4.47,  test loss 2.986405, test error 53.62
# Epoch   300, train loss 0.044913, train error 0.10,  test loss 4.655061, test error 54.58
# Epoch   400, train loss 0.014564, train error 0.00,  test loss 5.659683, test error 54.80
# Epoch   500, train loss 0.008402, train error 0.00,  test loss 6.269337, test error 54.95
# Epoch   600, train loss 0.005678, train error 0.00,  test loss 6.704002, test error 55.33
# Epoch   700, train loss 0.004181, train error 0.00,  test loss 7.042345, test error 55.28
# Epoch   800, train loss 0.003302, train error 0.00,  test loss 7.310351, test error 55.20
# Epoch   900, train loss 0.002710, train error 0.00,  test loss 7.539730, test error 55.22
# Training model with  60 hidden variables
# Epoch     0, train loss 2.033784, train error 75.68,  test loss 1.981604, test error 76.07
# Epoch   100, train loss 0.523344, train error 15.30,  test loss 1.803046, test error 51.00
# Epoch   200, train loss 0.091566, train error 0.53,  test loss 3.454190, test error 53.72
# Epoch   300, train loss 0.019028, train error 0.00,  test loss 4.798118, test error 54.70
# Epoch   400, train loss 0.008988, train error 0.00,  test loss 5.487435, test error 55.00
# Epoch   500, train loss 0.005730, train error 0.00,  test loss 5.951181, test error 55.05
# Epoch   600, train loss 0.004108, train error 0.00,  test loss 6.285430, test error 55.05
# Epoch   700, train loss 0.003159, train error 0.00,  test loss 6.551047, test error 55.12
# Epoch   800, train loss 0.002550, train error 0.00,  test loss 6.773167, test error 54.95
# Epoch   900, train loss 0.002126, train error 0.00,  test loss 6.964194, test error 55.00
# Training model with  70 hidden variables
# Epoch     0, train loss 2.063616, train error 75.88,  test loss 2.010705, test error 76.35
# Epoch   100, train loss 0.375778, train error 10.15,  test loss 1.969366, test error 52.70
# Epoch   200, train loss 0.033091, train error 0.00,  test loss 3.638304, test error 54.05
# Epoch   300, train loss 0.010796, train error 0.00,  test loss 4.444565, test error 54.70
# Epoch   400, train loss 0.005984, train error 0.00,  test loss 4.882390, test error 54.50
# Epoch   500, train loss 0.004019, train error 0.00,  test loss 5.189441, test error 54.65
# Epoch   600, train loss 0.002979, train error 0.00,  test loss 5.422067, test error 54.53
# Epoch   700, train loss 0.002337, train error 0.00,  test loss 5.609918, test error 54.62
# Epoch   800, train loss 0.001909, train error 0.00,  test loss 5.766654, test error 54.60
# Epoch   900, train loss 0.001607, train error 0.00,  test loss 5.901235, test error 54.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.020891, train error 74.50,  test loss 1.950735, test error 75.00
# Epoch   100, train loss 0.211528, train error 3.55,  test loss 2.114613, test error 51.60
# Epoch   200, train loss 0.019532, train error 0.00,  test loss 3.434586, test error 53.08
# Epoch   300, train loss 0.008050, train error 0.00,  test loss 4.001069, test error 53.28
# Epoch   400, train loss 0.004747, train error 0.00,  test loss 4.331123, test error 53.47
# Epoch   500, train loss 0.003284, train error 0.00,  test loss 4.569136, test error 53.40
# Epoch   600, train loss 0.002471, train error 0.00,  test loss 4.752538, test error 53.45
# Epoch   700, train loss 0.001961, train error 0.00,  test loss 4.903552, test error 53.42
# Epoch   800, train loss 0.001614, train error 0.00,  test loss 5.030986, test error 53.47
# Epoch   900, train loss 0.001365, train error 0.00,  test loss 5.138799, test error 53.38
# Training model with  90 hidden variables
# Epoch     0, train loss 2.017459, train error 73.32,  test loss 1.968474, test error 74.28
# Epoch   100, train loss 0.163043, train error 1.60,  test loss 2.225024, test error 52.40
# Epoch   200, train loss 0.015198, train error 0.00,  test loss 3.289072, test error 52.95
# Epoch   300, train loss 0.006691, train error 0.00,  test loss 3.738363, test error 52.95
# Epoch   400, train loss 0.004054, train error 0.00,  test loss 4.017565, test error 52.92
# Epoch   500, train loss 0.002842, train error 0.00,  test loss 4.216422, test error 52.90
# Epoch   600, train loss 0.002161, train error 0.00,  test loss 4.371574, test error 52.88
# Epoch   700, train loss 0.001725, train error 0.00,  test loss 4.497603, test error 52.88
# Epoch   800, train loss 0.001426, train error 0.00,  test loss 4.602973, test error 52.85
# Epoch   900, train loss 0.001211, train error 0.00,  test loss 4.696264, test error 52.88
# Training model with 100 hidden variables
# Epoch     0, train loss 2.024871, train error 75.85,  test loss 1.968404, test error 76.57
# Epoch   100, train loss 0.091862, train error 0.15,  test loss 2.245888, test error 50.08
# Epoch   200, train loss 0.012552, train error 0.00,  test loss 3.143003, test error 50.83
# Epoch   300, train loss 0.005746, train error 0.00,  test loss 3.510589, test error 51.03
# Epoch   400, train loss 0.003582, train error 0.00,  test loss 3.735077, test error 50.83
# Epoch   500, train loss 0.002546, train error 0.00,  test loss 3.907312, test error 50.92
# Epoch   600, train loss 0.001949, train error 0.00,  test loss 4.038741, test error 51.10
# Epoch   700, train loss 0.001565, train error 0.00,  test loss 4.148274, test error 51.12
# Epoch   800, train loss 0.001300, train error 0.00,  test loss 4.240019, test error 51.20
# Epoch   900, train loss 0.001106, train error 0.00,  test loss 4.320729, test error 51.20
# Training model with 120 hidden variables
# Epoch     0, train loss 1.983541, train error 73.88,  test loss 1.879888, test error 73.10
# Epoch   100, train loss 0.052210, train error 0.00,  test loss 2.232775, test error 50.78
# Epoch   200, train loss 0.009624, train error 0.00,  test loss 2.884322, test error 51.10
# Epoch   300, train loss 0.004773, train error 0.00,  test loss 3.178107, test error 51.25
# Epoch   400, train loss 0.003048, train error 0.00,  test loss 3.369251, test error 51.22
# Epoch   500, train loss 0.002199, train error 0.00,  test loss 3.508775, test error 51.20
# Epoch   600, train loss 0.001700, train error 0.00,  test loss 3.617979, test error 51.20
# Epoch   700, train loss 0.001374, train error 0.00,  test loss 3.710091, test error 51.33
# Epoch   800, train loss 0.001148, train error 0.00,  test loss 3.787937, test error 51.30
# Epoch   900, train loss 0.000981, train error 0.00,  test loss 3.854773, test error 51.25
# Training model with 140 hidden variables
# Epoch     0, train loss 1.955769, train error 71.07,  test loss 1.895234, test error 73.68
# Epoch   100, train loss 0.033377, train error 0.00,  test loss 2.137796, test error 48.95
# Epoch   200, train loss 0.007738, train error 0.00,  test loss 2.605633, test error 49.05
# Epoch   300, train loss 0.004011, train error 0.00,  test loss 2.828066, test error 48.78
# Epoch   400, train loss 0.002612, train error 0.00,  test loss 2.974430, test error 48.92
# Epoch   500, train loss 0.001903, train error 0.00,  test loss 3.086381, test error 48.75
# Epoch   600, train loss 0.001481, train error 0.00,  test loss 3.172167, test error 48.60
# Epoch   700, train loss 0.001204, train error 0.00,  test loss 3.245347, test error 48.70
# Epoch   800, train loss 0.001009, train error 0.00,  test loss 3.307624, test error 48.78
# Epoch   900, train loss 0.000865, train error 0.00,  test loss 3.361866, test error 48.80
# Training model with 160 hidden variables
# Epoch     0, train loss 1.953878, train error 71.75,  test loss 1.842111, test error 71.28
# Epoch   100, train loss 0.028815, train error 0.00,  test loss 2.036313, test error 49.40
# Epoch   200, train loss 0.007270, train error 0.00,  test loss 2.433226, test error 49.92
# Epoch   300, train loss 0.003793, train error 0.00,  test loss 2.626852, test error 50.08
# Epoch   400, train loss 0.002491, train error 0.00,  test loss 2.756083, test error 49.88
# Epoch   500, train loss 0.001825, train error 0.00,  test loss 2.852370, test error 50.03
# Epoch   600, train loss 0.001425, train error 0.00,  test loss 2.929909, test error 50.12
# Epoch   700, train loss 0.001160, train error 0.00,  test loss 2.994178, test error 50.25
# Epoch   800, train loss 0.000974, train error 0.00,  test loss 3.049886, test error 50.15
# Epoch   900, train loss 0.000836, train error 0.00,  test loss 3.097496, test error 50.15
# Training model with 180 hidden variables
# Epoch     0, train loss 1.918155, train error 69.97,  test loss 1.853038, test error 70.60
# Epoch   100, train loss 0.023469, train error 0.00,  test loss 2.025609, test error 47.28
# Epoch   200, train loss 0.006434, train error 0.00,  test loss 2.366625, test error 47.45
# Epoch   300, train loss 0.003457, train error 0.00,  test loss 2.535687, test error 47.35
# Epoch   400, train loss 0.002291, train error 0.00,  test loss 2.650545, test error 47.38
# Epoch   500, train loss 0.001691, train error 0.00,  test loss 2.738026, test error 47.30
# Epoch   600, train loss 0.001324, train error 0.00,  test loss 2.806484, test error 47.25
# Epoch   700, train loss 0.001082, train error 0.00,  test loss 2.864300, test error 47.33
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 2.914156, test error 47.38
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 2.958138, test error 47.17
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926000, train error 69.82,  test loss 1.850230, test error 71.28
# Epoch   100, train loss 0.021224, train error 0.00,  test loss 2.035821, test error 49.08
# Epoch   200, train loss 0.006129, train error 0.00,  test loss 2.354128, test error 49.12
# Epoch   300, train loss 0.003319, train error 0.00,  test loss 2.516549, test error 49.00
# Epoch   400, train loss 0.002217, train error 0.00,  test loss 2.628232, test error 49.05
# Epoch   500, train loss 0.001638, train error 0.00,  test loss 2.710722, test error 48.92
# Epoch   600, train loss 0.001287, train error 0.00,  test loss 2.777195, test error 48.88
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.833438, test error 49.05
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.880874, test error 49.03
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.923032, test error 49.08
# Training model with 250 hidden variables
# Epoch     0, train loss 1.878715, train error 68.32,  test loss 1.821402, test error 71.82
# Epoch   100, train loss 0.017308, train error 0.00,  test loss 1.941891, test error 48.65
# Epoch   200, train loss 0.005428, train error 0.00,  test loss 2.194636, test error 48.28
# Epoch   300, train loss 0.003023, train error 0.00,  test loss 2.330364, test error 48.05
# Epoch   400, train loss 0.002042, train error 0.00,  test loss 2.424348, test error 48.15
# Epoch   500, train loss 0.001520, train error 0.00,  test loss 2.494726, test error 48.17
# Epoch   600, train loss 0.001200, train error 0.00,  test loss 2.552073, test error 48.22
# Epoch   700, train loss 0.000985, train error 0.00,  test loss 2.599469, test error 48.10
# Epoch   800, train loss 0.000832, train error 0.00,  test loss 2.641017, test error 48.10
# Epoch   900, train loss 0.000717, train error 0.00,  test loss 2.676955, test error 48.10
# Training model with 300 hidden variables
# Epoch     0, train loss 1.869443, train error 67.50,  test loss 1.795430, test error 69.57
# Epoch   100, train loss 0.014553, train error 0.00,  test loss 1.805334, test error 46.10
# Epoch   200, train loss 0.004848, train error 0.00,  test loss 2.011689, test error 45.67
# Epoch   300, train loss 0.002739, train error 0.00,  test loss 2.126909, test error 45.47
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.204250, test error 45.38
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.264132, test error 45.12
# Epoch   600, train loss 0.001103, train error 0.00,  test loss 2.311991, test error 45.15
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.352799, test error 45.22
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.387581, test error 45.20
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.418636, test error 45.20
# Training model with 400 hidden variables
# Epoch     0, train loss 1.827585, train error 65.57,  test loss 1.742849, test error 67.53
# Epoch   100, train loss 0.011773, train error 0.00,  test loss 1.767031, test error 45.97
# Epoch   200, train loss 0.004190, train error 0.00,  test loss 1.942025, test error 45.45
# Epoch   300, train loss 0.002422, train error 0.00,  test loss 2.038195, test error 45.47
# Epoch   400, train loss 0.001668, train error 0.00,  test loss 2.106437, test error 45.40
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.158269, test error 45.45
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.200193, test error 45.53
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.235531, test error 45.53
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.266045, test error 45.53
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.292783, test error 45.47

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
